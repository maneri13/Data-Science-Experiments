# %% [markdown]
# <a href="https://colab.research.google.com/github/maneri13/Data-Science-Experiments/blob/master/5_XOR_Feature_Selection_Framework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Selection Framework
#
# The purpose of this notebook is to make it a bit easier to test feature selection and classification algorithms.

# %% [markdown]
# ##Imports

# %%
import scipy.io 
import numpy as np
import pandas as pd
import csv
import seaborn as sn

from sklearn.model_selection import *
from sklearn.feature_selection import *
from sklearn.ensemble import *
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import *
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.utils import class_weight
from sklearn.metrics import *


# !pip install pymrmr
import pymrmr
# Out:
# Collecting pymrmr
#   Downloading https://files.pythonhosted.org/packages/b3/ab/903712947a2f5cd1af249132885dbd81ae8bf8cfd30fb3b3f2beddab23e8/pymrmr-0.1.8.tar.gz (65kB)
#      |████████████████████████████████| 71kB 2.6MB/s
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from pymrmr) (1.18.5)
# Building wheels for collected packages: pymrmr
#   Building wheel for pymrmr (setup.py) ... done
#   Created wheel for pymrmr: filename=pymrmr-0.1.8-cp36-cp36m-linux_x86_64.whl size=256754 sha256=187be002a9bb1c8083db4bead75f262db3b65f118c3a0fce3e04cf15258edab8
#   Stored in directory: /root/.cache/pip/wheels/5b/ce/3a/bc9b80047f68973d909a35bb8e3062b7c7377510607ec35998
# Successfully built pymrmr
# Installing collected packages: pymrmr
# Successfully installed pymrmr-0.1.8

# %% [markdown]
# ## Data Initialization
#
# If you want to test more models, add them to the models dictionary. **Note: If any model is added to models dictionary, it should have the fit(), predict() and score() methods.**
#
# If you want to test more feature selection methods, add them to the fs dictionary. **Note: If any FS method is added to the dictionary, it should have fit and transform methods.**
#
# But in both cases, first read the methods in the section below and make sure the required functions are available.
#
# Source: https://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_selection

# %%
filename = '2_5XOR_rep1.csv'

metrics_columns = ['K-fold', 'FS', 'No. of columns', 'Columns selected', 'Algorithm', 'Accuracy', 'ROC', 'F1', 'APS']
metrics_df = pd.DataFrame(columns = metrics_columns)

models = [
          ('LogReg', LogisticRegression()), 
          ('RF', RandomForestClassifier()),
          ('KNN', KNeighborsClassifier()),
          ('SVM', SVC()), 
          ('GNB', GaussianNB()),
          ('ADA', AdaBoostClassifier()),
          ('XGB', XGBClassifier()),
          # ('Isolation Forest', IsolationForest()),
          # ('Stacking Classifier', StackingClassifier(estimators= 5)),
          # ('Voting Classifier', VotingClassifier(estimators= 5)),
          ('Bagging', BaggingClassifier(base_estimator= RandomForestClassifier())),
          ('Hist Gradient', HistGradientBoostingClassifier())
        ]

fs = [
      ('Chi-Squared(Best 2)', SelectKBest(chi2, k=2)),
      ('F-Classification(Best 2)', SelectKBest(f_classif, k=2)),
      ('FPR test', SelectFpr(chi2, alpha=0.8)),
      # ('FDR Test', SelectFdr(f_classif, alpha=0.8)),
      # ('FWE Test', SelectFwe(f_classif, alpha=0.9)),
      ('Variance Threshold', VarianceThreshold(threshold=(.2 * (1 - .2)))),
      ('RFE', RFE(SVR(kernel="linear"), n_features_to_select=5, step=1)),
      # ('Mutual Information Classification', mutual_info_classif(X,y)),
      ('Lasso(SVC)', SelectFromModel(LinearSVC(C=0.1, penalty="l1", dual=False))),
      ('Tree Classifier', SelectFromModel(RandomForestClassifier())),
      ('Logistic Regression', SelectFromModel(LogisticRegression())),
      ('AdaBoost', SelectFromModel(AdaBoostClassifier())),
      ('Extra Trees', SelectFromModel(ExtraTreesClassifier())),
      ('Gradient Boost', SelectFromModel(GradientBoostingClassifier()))
]

# %%
metrics_df.head()
# Out:
# Empty DataFrame
# Columns: [K-fold, FS, No. of columns, Columns selected, Algorithm, Accuracy, ROC, F1, APS]
# Index: []

# %% [markdown]
# ## File Upload

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b57a4eb-fb5e-4e88-b0d8-cdd429368181" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b57a4eb-fb5e-4e88-b0d8-cdd429368181">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %% [markdown]
# ## Initial Dataset Analysis
# **Note: Needs to be changed for every data set**

# %%
df = pd.read_csv(filename, header= None,
                 delimiter=',', encoding="utf-8")

y = df[5]
X = df.drop(labels= 5, axis= 1)
print(X.size)
print(X.head())
# Out:
# 3500
#    0  1  2  3  4
# 0  0  0  1  0  0
# 1  0  1  0  0  1
# 2  1  0  0  0  0
# 3  0  1  0  1  0
# 4  0  1  0  0  1

# %% [markdown]
# ## Methods
#
# *   data_split: Reads csv and returns X(dataset) and y(target). **Note: Needs to be changed for every data set.**
# *   model_test: Takes split data set as 4 inputs. Loops over models dictionary and tests all models.
# *   feature_selection:  Takes split data set as 4 inputs. loops over fs dictionary and tests each feature selection method. Last line of method calls the model_test method in each loop.
# *   Main: Splits data into K-folds and runs feature_selection method in loop.

# %%
def data_split():
  df = pd.read_csv(filename, header= None,
                 delimiter=',', encoding="utf-8")
  y = df[5]
  X = df.drop(labels= 5, axis= 1)
  return X,y

def model_test(k_fold, fs, no_columns, sel_columns, X_train, y_train, X_test, y_test):
  for name, model in models:
    clf = model
    print(name)
    clf.fit(X_train, y_train)
    predictions = clf.predict(X_test)
    roc = roc_auc_score(y_test, predictions)
    f1 = f1_score(y_test, predictions)
    aps = average_precision_score(y_test, predictions)
    score = clf.score(X_test, y_test)
    print('Accuracy Score: ' + str(score))
    print('ROC Score: ' + str(roc))
    print('F1 score: ' + str(f1))
    print('Average Precision Score: ' + str(aps))
    row_metrics = pd.DataFrame([
                         [k_fold, fs, no_columns, sel_columns,name, score, roc, f1, aps] 
                         ], columns = metrics_columns)
    global metrics_df 
    metrics_df = metrics_df.append(row_metrics, ignore_index=True)


def feature_selection(k_fold, X_train, y_train, X_test, y_test):
  for name, selection in fs:
    print('\nOriginal number of rows and columns in training data set: ' + str(X_train.shape))
    print('Original number of rows and columns in testing data set: ' + str(X_test.shape))
    print('Feature Selection Method: ' + name)
    sel = selection
    sel.fit(X_train, y_train)
    no_col = sum(sel.get_support())
    sel_col = [x for x in X.columns if x  in X.columns[sel.get_support()]]
    print('Number of features selected: ' + str(no_col))
    print( 'Number of features not selected: ' +
     str( len([
        x for x in X.columns
        if x not in X.columns[sel.get_support()]
    ])))
    print('columns selected: ' + str(sel_col))
    X_new_train = sel.transform(X_train)
    X_new_test = sel.transform(X_test)
    print('The new training set has rows and columns: ' + str(X_new_train.shape))
    print('The new testing set has rows and columns: ' + str(X_new_test.shape)+ '\n')
    model_test(k_fold, name, no_col, sel_col, X_new_train, y_train, X_new_test, y_test)

def Main():
  kf = KFold(n_splits=10, random_state= 1, shuffle = True)
  count = 0
  for train_index, test_index in kf.split(X):
    print("This is Fold: " + str(count))

    data_split()
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    print('This is the size of the training set: ' + str(X_train.shape))
    print('This is the size of the testing set: ' + str(X_test.shape))

    feature_selection(count, X_train, y_train, X_test, y_test)
    count = count + 1

# %% [markdown]
# ## Program Call

# %%
metrics_df.head()
Main()
# Out:
# Streaming output truncated to the last 5000 lines.
# GNB
# Accuracy Score: 0.6
# ROC Score: 0.6003276003276002
# F1 score: 0.588235294117647
# Average Precision Score: 0.532034632034632
# ADA
# Accuracy Score: 0.6
# ROC Score: 0.6003276003276002
# F1 score: 0.588235294117647
# Average Precision Score: 0.532034632034632
# XGB
# Accuracy Score: 0.6
# ROC Score: 0.6036036036036037
# F1 score: 0.611111111111111
# Average Precision Score: 0.5332112332112332
# Bagging
# Accuracy Score: 0.4714285714285714
# ROC Score: 0.48525798525798525
# F1 score: 0.5647058823529413
# Average Precision Score: 0.46423576423576424
# Hist Gradient
# Accuracy Score: 0.6
# ROC Score: 0.6036036036036037
# F1 score: 0.611111111111111
# Average Precision Score: 0.5332112332112332
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Extra Trees
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# ADA
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Gradient Boost
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# ADA
# Accuracy Score: 0.6428571428571429
# ROC Score: 0.6621621621621622
# F1 score: 0.7252747252747253
# Average Precision Score: 0.5689655172413793
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# This is Fold: 2
# This is the size of the training set: (630, 5)
# This is the size of the testing set: (70, 5)
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Chi-Squared(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [0, 1]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# KNN
# Accuracy Score: 0.5142857142857142
# ROC Score: 0.4747725392886683
# F1 score: 0.6530612244897959
# Average Precision Score: 0.5450239026510213
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Bagging
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: F-Classification(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [0, 1]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# KNN
# Accuracy Score: 0.5142857142857142
# ROC Score: 0.4747725392886683
# F1 score: 0.6530612244897959
# Average Precision Score: 0.5450239026510213
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Bagging
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: FPR test
# Number of features selected: 3
# Number of features not selected: 2
# columns selected: [0, 1, 2]
# The new training set has rows and columns: (630, 3)
# The new testing set has rows and columns: (70, 3)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# KNN
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5140612076095947
# F1 score: 0.6024096385542169
# Average Precision Score: 0.5642191142191143
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# Bagging
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Variance Threshold
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: RFE
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.47311827956989244
# F1 score: 0.40625000000000006
# Average Precision Score: 0.5447619047619048
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Lasso(SVC)
# Number of features selected: 3
# Number of features not selected: 2
# columns selected: [0, 1, 2]
# The new training set has rows and columns: (630, 3)
# The new testing set has rows and columns: (70, 3)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# KNN
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5140612076095947
# F1 score: 0.6024096385542169
# Average Precision Score: 0.5642191142191143
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
# Bagging
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.43465674110835406
# F1 score: 0.3278688524590163
# Average Precision Score: 0.5308358308358309
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Tree Classifier
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# ADA
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Logistic Regression
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [0, 1]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# KNN
# Accuracy Score: 0.5142857142857142
# ROC Score: 0.4747725392886683
# F1 score: 0.6530612244897959
# Average Precision Score: 0.5450239026510213
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# GNB
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# ADA
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4698097601323407
# F1 score: 0.42424242424242425
# Average Precision Score: 0.5432777099443766
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Bagging
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.44458229942100913
# F1 score: 0.2545454545454545
# Average Precision Score: 0.5356684981684982
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: AdaBoost
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [2, 3]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# RF
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# KNN
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5571428571428572
# SVM
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# GNB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# ADA
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# XGB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
# Bagging
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5571428571428572
# Hist Gradient
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5595533498759304
# F1 score: 0.5753424657534247
# Average Precision Score: 0.5897220426632191
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Extra Trees
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# ADA
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Gradient Boost
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# ADA
# Accuracy Score: 0.6857142857142857
# ROC Score: 0.717948717948718
# F1 score: 0.6071428571428571
# Average Precision Score: 0.7501831501831502
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# This is Fold: 3
# This is the size of the training set: (630, 5)
# This is the size of the testing set: (70, 5)
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Chi-Squared(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# RF
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# KNN
# Accuracy Score: 0.5714285714285714
# ROC Score: 0.5751633986928104
# F1 score: 0.5161290322580646
# Average Precision Score: 0.5592185592185592
# SVM
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# GNB
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# XGB
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Bagging
# Accuracy Score: 0.34285714285714286
# ROC Score: 0.34558823529411764
# F1 score: 0.28125000000000006
# Average Precision Score: 0.4660714285714285
# Hist Gradient
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: F-Classification(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# RF
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# KNN
# Accuracy Score: 0.5714285714285714
# ROC Score: 0.5751633986928104
# F1 score: 0.5161290322580646
# Average Precision Score: 0.5592185592185592
# SVM
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# GNB
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# XGB
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Bagging
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Hist Gradient
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: FPR test
# Number of features selected: 3
# Number of features not selected: 2
# columns selected: [1, 2, 3]
# The new training set has rows and columns: (630, 3)
# The new testing set has rows and columns: (70, 3)
#
# LogReg
# Accuracy Score: 0.4
# ROC Score: 0.4011437908496732
# F1 score: 0.38235294117647056
# Average Precision Score: 0.4752728174603174
# RF
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# KNN
# Accuracy Score: 0.5428571428571428
# ROC Score: 0.542483660130719
# F1 score: 0.5555555555555556
# Average Precision Score: 0.5372134038800706
# SVM
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# GNB
# Accuracy Score: 0.4
# ROC Score: 0.4011437908496732
# F1 score: 0.38235294117647056
# Average Precision Score: 0.4752728174603174
# ADA
# Accuracy Score: 0.4
# ROC Score: 0.4011437908496732
# F1 score: 0.38235294117647056
# Average Precision Score: 0.4752728174603174
# XGB
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Bagging
# Accuracy Score: 0.4
# ROC Score: 0.3978758169934641
# F1 score: 0.4473684210526316
# Average Precision Score: 0.47212301587301586
# Hist Gradient
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.4305555555555556
# F1 score: 0.39393939393939387
# Average Precision Score: 0.48505291005290996
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Variance Threshold
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4452614379084967
# F1 score: 0.39999999999999997
# Average Precision Score: 0.4904488232074439
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.48937908496732024
# F1 score: 0.4193548387096774
# Average Precision Score: 0.5091269841269841
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4452614379084967
# F1 score: 0.39999999999999997
# Average Precision Score: 0.4904488232074439
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: RFE
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4452614379084967
# F1 score: 0.39999999999999997
# Average Precision Score: 0.4904488232074439
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.48937908496732024
# F1 score: 0.4193548387096774
# Average Precision Score: 0.5091269841269841
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4452614379084967
# F1 score: 0.39999999999999997
# Average Precision Score: 0.4904488232074439
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Lasso(SVC)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# RF
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# KNN
# Accuracy Score: 0.5714285714285714
# ROC Score: 0.5751633986928104
# F1 score: 0.5161290322580646
# Average Precision Score: 0.5592185592185592
# SVM
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# GNB
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# XGB
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Bagging
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5277777777777778
# F1 score: 0.547945205479452
# Average Precision Score: 0.5288717288717288
# Hist Gradient
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Tree Classifier
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Logistic Regression
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# RF
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# KNN
# Accuracy Score: 0.5714285714285714
# ROC Score: 0.5751633986928104
# F1 score: 0.5161290322580646
# Average Precision Score: 0.5592185592185592
# SVM
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# GNB
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# ADA
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4526143790849674
# F1 score: 0.1702127659574468
# Average Precision Score: 0.49754689754689746
# XGB
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Bagging
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
# Hist Gradient
# Accuracy Score: 0.42857142857142855
# ROC Score: 0.42075163398692816
# F1 score: 0.5555555555555555
# Average Precision Score: 0.47864491475602583
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: AdaBoost
# Number of features selected: 3
# Number of features not selected: 2
# columns selected: [0, 1, 3]
# The new training set has rows and columns: (630, 3)
# The new testing set has rows and columns: (70, 3)
#
# LogReg
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5277777777777778
# F1 score: 0.547945205479452
# Average Precision Score: 0.5288717288717288
# RF
# Accuracy Score: 0.5
# ROC Score: 0.49918300653594766
# F1 score: 0.5205479452054794
# Average Precision Score: 0.5138781638781638
# KNN
# Accuracy Score: 0.5142857142857142
# ROC Score: 0.5106209150326797
# F1 score: 0.575
# Average Precision Score: 0.5196789321789321
# SVM
# Accuracy Score: 0.5
# ROC Score: 0.49918300653594766
# F1 score: 0.5205479452054794
# Average Precision Score: 0.5138781638781638
# GNB
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5277777777777778
# F1 score: 0.547945205479452
# Average Precision Score: 0.5288717288717288
# ADA
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5277777777777778
# F1 score: 0.547945205479452
# Average Precision Score: 0.5288717288717288
# XGB
# Accuracy Score: 0.5
# ROC Score: 0.49918300653594766
# F1 score: 0.5205479452054794
# Average Precision Score: 0.5138781638781638
# Bagging
# Accuracy Score: 0.4714285714285714
# ROC Score: 0.47549019607843135
# F1 score: 0.39344262295081966
# Average Precision Score: 0.5028571428571429
# Hist Gradient
# Accuracy Score: 0.5
# ROC Score: 0.49918300653594766
# F1 score: 0.5205479452054794
# Average Precision Score: 0.5138781638781638
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Extra Trees
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Gradient Boost
# Number of features selected: 1
# Number of features not selected: 4
# columns selected: [3]
# The new training set has rows and columns: (630, 1)
# The new testing set has rows and columns: (70, 1)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# KNN
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# Bagging
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41503267973856206
# F1 score: 0.40579710144927533
# Average Precision Score: 0.4792688792688793
# This is Fold: 4
# This is the size of the training set: (630, 5)
# This is the size of the testing set: (70, 5)
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Chi-Squared(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# KNN
# Accuracy Score: 0.4714285714285714
# ROC Score: 0.47542997542997545
# F1 score: 0.4477611940298507
# Average Precision Score: 0.5169884169884169
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# Bagging
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: F-Classification(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# KNN
# Accuracy Score: 0.4714285714285714
# ROC Score: 0.47542997542997545
# F1 score: 0.4477611940298507
# Average Precision Score: 0.5169884169884169
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# Bagging
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# Hist Gradient
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: FPR test
# Number of features selected: 4
# Number of features not selected: 1
# columns selected: [0, 1, 2, 4]
# The new training set has rows and columns: (630, 4)
# The new testing set has rows and columns: (70, 4)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.45536445536445536
# F1 score: 0.4864864864864865
# Average Precision Score: 0.5080976729625378
# KNN
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4402129402129402
# F1 score: 0.4799999999999999
# Average Precision Score: 0.501869538711644
# SVM
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4434889434889435
# F1 score: 0.4507042253521127
# Average Precision Score: 0.5034976152623212
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.40990990990990994
# F1 score: 0.4675324675324675
# Average Precision Score: 0.49034749034749037
# Bagging
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.45536445536445536
# F1 score: 0.4864864864864865
# Average Precision Score: 0.5080976729625378
# Hist Gradient
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.45536445536445536
# F1 score: 0.4864864864864865
# Average Precision Score: 0.5080976729625378
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Variance Threshold
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: RFE
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Lasso(SVC)
# Number of features selected: 4
# Number of features not selected: 1
# columns selected: [0, 1, 2, 4]
# The new training set has rows and columns: (630, 4)
# The new testing set has rows and columns: (70, 4)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# RF
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.45536445536445536
# F1 score: 0.4864864864864865
# Average Precision Score: 0.5080976729625378
# KNN
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4402129402129402
# F1 score: 0.4799999999999999
# Average Precision Score: 0.501869538711644
# SVM
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.4434889434889435
# F1 score: 0.4507042253521127
# Average Precision Score: 0.5034976152623212
# GNB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# ADA
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# Average Precision Score: 0.4951093951093951
# XGB
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.40990990990990994
# F1 score: 0.4675324675324675
# Average Precision Score: 0.49034749034749037
# Bagging
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.43857493857493857
# F1 score: 0.4935064935064935
# Average Precision Score: 0.501061776061776
# Hist Gradient
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.45536445536445536
# F1 score: 0.4864864864864865
# Average Precision Score: 0.5080976729625378
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Tree Classifier
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4
# ROC Score: 0.398034398034398
# F1 score: 0.43243243243243246
# Average Precision Score: 0.48699780861943026
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4
# ROC Score: 0.398034398034398
# F1 score: 0.43243243243243246
# Average Precision Score: 0.48699780861943026
# ADA
# Accuracy Score: 0.4
# ROC Score: 0.398034398034398
# F1 score: 0.43243243243243246
# Average Precision Score: 0.48699780861943026
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Logistic Regression
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [1, 2]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4180999180999181
# F1 score: 0.3880597014925374
# ...
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# RF
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# KNN
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41666666666666663
# F1 score: 0.36923076923076925
# Average Precision Score: 0.4807881773399015
# SVM
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# GNB
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# ADA
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# XGB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# Bagging
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# Hist Gradient
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: F-Classification(Best 2)
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [0, 1]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# RF
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# KNN
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41666666666666663
# F1 score: 0.36923076923076925
# Average Precision Score: 0.4807881773399015
# SVM
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# GNB
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# ADA
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# XGB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# Bagging
# Accuracy Score: 0.5857142857142857
# ROC Score: 0.5833333333333333
# F1 score: 0.6233766233766234
# Average Precision Score: 0.5616724738675958
# Hist Gradient
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: FPR test
# Number of features selected: 4
# Number of features not selected: 1
# columns selected: [0, 1, 2, 3]
# The new training set has rows and columns: (630, 4)
# The new testing set has rows and columns: (70, 4)
#
# LogReg
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# RF
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.4836601307189542
# F1 score: 0.5263157894736842
# Average Precision Score: 0.5063492063492063
# KNN
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4542483660130719
# F1 score: 0.5128205128205129
# Average Precision Score: 0.49312169312169307
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41911764705882354
# F1 score: 0.3050847457627119
# Average Precision Score: 0.4835403726708074
# GNB
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# ADA
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# XGB
# Accuracy Score: 0.4
# ROC Score: 0.4027777777777778
# F1 score: 0.34375000000000006
# Average Precision Score: 0.47718253968253965
# Bagging
# Accuracy Score: 0.44285714285714284
# ROC Score: 0.446078431372549
# F1 score: 0.380952380952381
# Average Precision Score: 0.491005291005291
# Hist Gradient
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.46323529411764713
# F1 score: 0.32142857142857145
# Average Precision Score: 0.49821428571428567
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Variance Threshold
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# ADA
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: RFE
# Number of features selected: 5
# Number of features not selected: 0
# columns selected: [0, 1, 2, 3, 4]
# The new training set has rows and columns: (630, 5)
# The new testing set has rows and columns: (70, 5)
#
# LogReg
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# ADA
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Lasso(SVC)
# Number of features selected: 4
# Number of features not selected: 1
# columns selected: [0, 1, 2, 3]
# The new training set has rows and columns: (630, 4)
# The new testing set has rows and columns: (70, 4)
#
# LogReg
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# RF
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.4158496732026144
# F1 score: 0.3880597014925373
# Average Precision Score: 0.48000512032770093
# KNN
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.4542483660130719
# F1 score: 0.5128205128205129
# Average Precision Score: 0.49312169312169307
# SVM
# Accuracy Score: 0.4142857142857143
# ROC Score: 0.41911764705882354
# F1 score: 0.3050847457627119
# Average Precision Score: 0.4835403726708074
# GNB
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# ADA
# Accuracy Score: 0.5285714285714286
# ROC Score: 0.5253267973856208
# F1 score: 0.5822784810126581
# Average Precision Score: 0.5274455518641565
# XGB
# Accuracy Score: 0.4
# ROC Score: 0.4027777777777778
# F1 score: 0.34375000000000006
# Average Precision Score: 0.47718253968253965
# Bagging
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5588235294117647
# F1 score: 0.537313432835821
# Average Precision Score: 0.5474654377880184
# Hist Gradient
# Accuracy Score: 0.45714285714285713
# ROC Score: 0.46323529411764713
# F1 score: 0.32142857142857145
# Average Precision Score: 0.49821428571428567
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Tree Classifier
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# ADA
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Logistic Regression
# Number of features selected: 3
# Number of features not selected: 2
# columns selected: [0, 1, 2]
# The new training set has rows and columns: (630, 3)
# The new testing set has rows and columns: (70, 3)
#
# LogReg
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5531045751633987
# F1 score: 0.6172839506172839
# Average Precision Score: 0.5429453262786597
# RF
# Accuracy Score: 0.6285714285714286
# ROC Score: 0.6274509803921569
# F1 score: 0.6486486486486486
# Average Precision Score: 0.5924812030075188
# KNN
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.48529411764705876
# F1 score: 0.5
# Average Precision Score: 0.5071428571428571
# SVM
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# GNB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5531045751633987
# F1 score: 0.6172839506172839
# Average Precision Score: 0.5429453262786597
# ADA
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5531045751633987
# F1 score: 0.6172839506172839
# Average Precision Score: 0.5429453262786597
# XGB
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
# Bagging
# Accuracy Score: 0.5428571428571428
# ROC Score: 0.542483660130719
# F1 score: 0.5555555555555556
# Average Precision Score: 0.5372134038800706
# Hist Gradient
# Accuracy Score: 0.5571428571428572
# ROC Score: 0.5629084967320261
# F1 score: 0.45614035087719296
# Average Precision Score: 0.552116402116402
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: AdaBoost
# Number of features selected: 4
# Number of features not selected: 1
# columns selected: [0, 2, 3, 4]
# The new training set has rows and columns: (630, 4)
# The new testing set has rows and columns: (70, 4)
#
# LogReg
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.4836601307189542
# F1 score: 0.5263157894736842
# Average Precision Score: 0.5063492063492063
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.4836601307189542
# F1 score: 0.5263157894736842
# Average Precision Score: 0.5063492063492063
# ADA
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.4836601307189542
# F1 score: 0.5263157894736842
# Average Precision Score: 0.5063492063492063
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Extra Trees
# Number of features selected: 2
# Number of features not selected: 3
# columns selected: [3, 4]
# The new training set has rows and columns: (630, 2)
# The new testing set has rows and columns: (70, 2)
#
# LogReg
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# RF
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# KNN
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# SVM
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# GNB
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# ADA
# Accuracy Score: 0.37142857142857144
# ROC Score: 0.37173202614379086
# F1 score: 0.3714285714285714
# Average Precision Score: 0.46664332399626507
# XGB
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Bagging
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
# Hist Gradient
# Accuracy Score: 1.0
# ROC Score: 1.0
# F1 score: 1.0
# Average Precision Score: 1.0
#
# Original number of rows and columns in training data set: (630, 5)
# Original number of rows and columns in testing data set: (70, 5)
# Feature Selection Method: Gradient Boost
# Number of features selected: 1
# Number of features not selected: 4
# columns selected: [4]
# The new training set has rows and columns: (630, 1)
# The new testing set has rows and columns: (70, 1)
#
# LogReg
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# RF
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# KNN
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# SVM
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# GNB
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.48937908496732024
# F1 score: 0.4193548387096774
# Average Precision Score: 0.5091269841269841
# ADA
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# XGB
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142
# Bagging
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.48937908496732024
# F1 score: 0.4193548387096774
# Average Precision Score: 0.5091269841269841
# Hist Gradient
# Accuracy Score: 0.4857142857142857
# ROC Score: 0.5
# F1 score: 0.0
# Average Precision Score: 0.5142857142857142

# %% [markdown]
# ## Metrics

# %%
print(metrics_df.shape) #Should be 1170 rows
metrics_df.head(150)
# Out:
# (990, 9)
#     K-fold                   FS No. of columns  ...       ROC        F1       APS
# 0        0  Chi-Squared(Best 2)              2  ...  0.426699  0.393939  0.440903
# 1        0  Chi-Squared(Best 2)              2  ...  0.426699  0.393939  0.440903
# 2        0  Chi-Squared(Best 2)              2  ...  0.573301  0.571429  0.513315
# 3        0  Chi-Squared(Best 2)              2  ...  0.426699  0.393939  0.440903
# 4        0  Chi-Squared(Best 2)              2  ...  0.426699  0.393939  0.440903
# ..     ...                  ...            ...  ...       ...       ...       ...
# 145      1           Lasso(SVC)              5  ...  1.000000  1.000000  1.000000
# 146      1           Lasso(SVC)              5  ...  1.000000  1.000000  1.000000
# 147      1           Lasso(SVC)              5  ...  1.000000  1.000000  1.000000
# 148      1           Lasso(SVC)              5  ...  0.519247  0.540541  0.481354
# 149      1           Lasso(SVC)              5  ...  0.519247  0.540541  0.481354
#
# [150 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('drive')
metrics_df.to_csv('Dataset_5_XOR.csv')
# !cp Dataset_5_XOR.csv "drive/My Drive/"
